# %%
import pandas as pd
import numpy as np

# %%
names = ['Year','Month','ppt(mm)','tmax(degC)','tmin(degC)','aet(mm)','PDSI(unitless)','state','district','cluster14','cluster15','cluster18','cluster20','cluster25','cluster27','cluster30','cluster35']

# %%
df = pd.read_csv("C:/Users/H/Documents/agroclimatic_clusters.txt", sep=',', header=None, names=names, index_col=False, engine='python')

# %%
df.head()
# Out:
#    Year  Month  ppt(mm)  tmax(degC)  tmin(degC)  aet(mm)  PDSI(unitless)  \
# 0  1958      1        0        32.1        16.6        2            -0.1
# 1  1958      2        0        34.2        18.4        2            -0.5
# 2  1958      3       17        38.5        21.5       17             0.2
# 3  1958      4       32        40.2        25.3       32             0.8
# 4  1958      5       68        40.5        25.8       65             1.5
#
#          state district  cluster14  cluster15  cluster18  cluster20  \
# 0  maharashtra  solapur          8          7          0          7
# 1  maharashtra  solapur          8          7          0          7
# 2  maharashtra  solapur          8          7          0          7
# 3  maharashtra  solapur          8          7          0          7
# 4  maharashtra  solapur          8          7          0          7
#
#    cluster25  cluster27  cluster30  cluster35
# 0         12         23         15         23
# 1         12         23         15         23
# 2         12         23         15         23
# 3         12         23         15         23
# 4         12         23         15         23

# %%
df['state'].value_counts()
# Out:
# uttar pradesh             52080
# madhya pradesh            35712
# bihar                     27528
# maharashtra               25296
# rajasthan                 23808
# orissa                    22320
# tamil nadu                22320
# karnataka                 20088
# gujarat                   18600
# andhra pradesh            17112
# assam                     17112
# jharkhand                 16368
# west bengal               14136
# haryana                   14136
# punjab                    12648
# chhattisgarh              11904
# arunachal pradesh         11160
# jammu and kashmir         10416
# kerala                    10416
# uttaranchal                9672
# himachal pradesh           8928
# manipur                    6696
# mizoram                    5952
# nagaland                   5952
# meghalaya                  5208
# puducherry                 2976
# sikkim                     2976
# tripura                    2976
# andaman and nicobar        1488
# goa                        1488
# daman and diu              1488
# chandigarh                  744
# lakshadweep                 744
# dadra and nagar haveli      744
# delhi                       744
# Name: state, dtype: int64

# %%
a = []
for i in range(len(df)):
    if df['state'][i]!='maharashtra':
        a.append(i)

# %%
df = df.drop(a)

# %%
df.head()
# Out:
#    Year  Month  ppt(mm)  tmax(degC)  tmin(degC)  aet(mm)  PDSI(unitless)  \
# 0  1958      1        0        32.1        16.6        2            -0.1
# 1  1958      2        0        34.2        18.4        2            -0.5
# 2  1958      3       17        38.5        21.5       17             0.2
# 3  1958      4       32        40.2        25.3       32             0.8
# 4  1958      5       68        40.5        25.8       65             1.5
#
#          state district  cluster14  cluster15  cluster18  cluster20  \
# 0  maharashtra  solapur          8          7          0          7
# 1  maharashtra  solapur          8          7          0          7
# 2  maharashtra  solapur          8          7          0          7
# 3  maharashtra  solapur          8          7          0          7
# 4  maharashtra  solapur          8          7          0          7
#
#    cluster25  cluster27  cluster30  cluster35
# 0         12         23         15         23
# 1         12         23         15         23
# 2         12         23         15         23
# 3         12         23         15         23
# 4         12         23         15         23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25296 entries, 0 to 434495
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            25296 non-null  int64
#  1   Month           25296 non-null  int64
#  2   ppt(mm)         25296 non-null  int64
#  3   tmax(degC)      25296 non-null  float64
#  4   tmin(degC)      25296 non-null  float64
#  5   aet(mm)         25296 non-null  int64
#  6   PDSI(unitless)  25296 non-null  float64
#  7   state           25296 non-null  object
#  8   district        25296 non-null  object
#  9   cluster14       25296 non-null  int64
#  10  cluster15       25296 non-null  int64
#  11  cluster18       25296 non-null  int64
#  12  cluster20       25296 non-null  int64
#  13  cluster25       25296 non-null  int64
#  14  cluster27       25296 non-null  int64
#  15  cluster30       25296 non-null  int64
#  16  cluster35       25296 non-null  int64
# dtypes: float64(3), int64(12), object(2)
# memory usage: 3.5+ MB

# %%
conditions = df[['Year','Month','ppt(mm)','tmax(degC)','tmin(degC)','aet(mm)','PDSI(unitless)','district']]
conditions.shape
# Out:
# (25296, 8)

# %%
conditions.isnull().sum(axis = 0)
# Out:
# Year              0
# Month             0
# ppt(mm)           0
# tmax(degC)        0
# tmin(degC)        0
# aet(mm)           0
# PDSI(unitless)    0
# district          0
# dtype: int64

# %%
conditions["date"] = conditions['Month'].astype('str')+'-'+conditions["Year"].astype(str)
conditions.head()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    Year  Month  ppt(mm)  tmax(degC)  tmin(degC)  aet(mm)  PDSI(unitless)  \
# 0  1958      1        0        32.1        16.6        2            -0.1
# 1  1958      2        0        34.2        18.4        2            -0.5
# 2  1958      3       17        38.5        21.5       17             0.2
# 3  1958      4       32        40.2        25.3       32             0.8
# 4  1958      5       68        40.5        25.8       65             1.5
#
#   district    date
# 0  solapur  1-1958
# 1  solapur  2-1958
# 2  solapur  3-1958
# 3  solapur  4-1958
# 4  solapur  5-1958

# %%
conditions['Day'] = [1] * len(conditions['Month'])
conditions['date'] = pd.to_datetime(conditions[['Year','Month','Day']])
# Out:
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
conditions.head()
# Out:
#    Year  Month  ppt(mm)  tmax(degC)  tmin(degC)  aet(mm)  PDSI(unitless)  \
# 0  1958      1        0        32.1        16.6        2            -0.1
# 1  1958      2        0        34.2        18.4        2            -0.5
# 2  1958      3       17        38.5        21.5       17             0.2
# 3  1958      4       32        40.2        25.3       32             0.8
# 4  1958      5       68        40.5        25.8       65             1.5
#
#   district       date  Day
# 0  solapur 1958-01-01    1
# 1  solapur 1958-02-01    1
# 2  solapur 1958-03-01    1
# 3  solapur 1958-04-01    1
# 4  solapur 1958-05-01    1

# %%
conditions['mid_temp'] = 0.5*(conditions['tmax(degC)']+conditions['tmin(degC)'])
conditions.drop(columns = ['tmax(degC)','tmin(degC)'],inplace = True)
conditions.head()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\H\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Year  Month  ppt(mm)  aet(mm)  PDSI(unitless) district       date  Day  \
# 0  1958      1        0        2            -0.1  solapur 1958-01-01    1
# 1  1958      2        0        2            -0.5  solapur 1958-02-01    1
# 2  1958      3       17       17             0.2  solapur 1958-03-01    1
# 3  1958      4       32       32             0.8  solapur 1958-04-01    1
# 4  1958      5       68       65             1.5  solapur 1958-05-01    1
#
#    mid_temp
# 0     24.35
# 1     26.30
# 2     30.00
# 3     32.75
# 4     33.15

# %%
conditions.tail()
# Out:
#         Year  Month  ppt(mm)  aet(mm)  PDSI(unitless) district       date  \
# 434491  2019      8      206      127             1.3    latur 2019-08-01
# 434492  2019      9      258      104             1.9    latur 2019-09-01
# 434493  2019     10      187      101             4.6    latur 2019-10-01
# 434494  2019     11       20       68             5.3    latur 2019-11-01
# 434495  2019     12        6       29             5.8    latur 2019-12-01
#
#         Day  mid_temp
# 434491    1     25.90
# 434492    1     25.45
# 434493    1     24.80
# 434494    1     23.80
# 434495    1     22.40

# %%
conditions_truncated = conditions.loc[(conditions['Year']>1980) & (conditions['Year']<2019)]
conditions_val = conditions.loc[conditions['Year']==2019]

train = conditions_truncated[['date','ppt(mm)','mid_temp','aet(mm)','district']]
train.rename(columns = {'mid_temp':'y'}, inplace = True)

train.reset_index(inplace = True)
train.drop(columns = 'index',inplace = True)
train.head()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\H\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         date  ppt(mm)      y  aet(mm) district
# 0 1981-01-01       13  23.15       14  solapur
# 1 1981-02-01        0  26.50        1  solapur
# 2 1981-03-01       17  29.45       17  solapur
# 3 1981-04-01       14  32.55       14  solapur
# 4 1981-05-01       38  32.90       36  solapur

# %%
conditions_val
# Out:
#         Year  Month  ppt(mm)  aet(mm)  PDSI(unitless) district       date  \
# 732     2019      1        0        1            -2.1  solapur 2019-01-01
# 733     2019      2        0        0            -2.1  solapur 2019-02-01
# 734     2019      3        0        1            -2.2  solapur 2019-03-01
# 735     2019      4        4        4            -2.4  solapur 2019-04-01
# 736     2019      5        2        2            -3.3  solapur 2019-05-01
# ...      ...    ...      ...      ...             ...      ...        ...
# 434491  2019      8      206      127             1.3    latur 2019-08-01
# 434492  2019      9      258      104             1.9    latur 2019-09-01
# 434493  2019     10      187      101             4.6    latur 2019-10-01
# 434494  2019     11       20       68             5.3    latur 2019-11-01
# 434495  2019     12        6       29             5.8    latur 2019-12-01
#
#         Day  mid_temp
# 732       1     23.00
# 733       1     26.65
# 734       1     31.05
# 735       1     34.25
# 736       1     35.60
# ...     ...       ...
# 434491    1     25.90
# 434492    1     25.45
# 434493    1     24.80
# 434494    1     23.80
# 434495    1     22.40
#
# [408 rows x 9 columns]

# %%
from fbprophet import Prophet

# %%
model = Prophet()

# %%
conditions_truncated.rename(columns = {'date':'ds'}, inplace = True)
# Out:
# C:\Users\H\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
train.rename(columns = {'date':'ds'}, inplace = True)

# %%
p = conditions[['mid_temp','Year']]

# %%
p
# Out:
#         mid_temp  Year
# 0          24.35  1958
# 1          26.30  1958
# 2          30.00  1958
# 3          32.75  1958
# 4          33.15  1958
# ...          ...   ...
# 434491     25.90  2019
# 434492     25.45  2019
# 434493     24.80  2019
# 434494     23.80  2019
# 434495     22.40  2019
#
# [25296 rows x 2 columns]

# %%
k = []

# %%
p = p.loc[p['Year']==2019]

# %%
p = p.drop(k)

# %%
p
# Out:
#         mid_temp  Year
# 732        23.00  2019
# 733        26.65  2019
# 734        31.05  2019
# 735        34.25  2019
# 736        35.60  2019
# ...          ...   ...
# 434491     25.90  2019
# 434492     25.45  2019
# 434493     24.80  2019
# 434494     23.80  2019
# 434495     22.40  2019
#
# [408 rows x 2 columns]

# %%
train.tail()
# Out:
#               ds  ppt(mm)      y  aet(mm) district
# 15499 2018-08-01      142  24.05      120    latur
# 15500 2018-09-01      131  24.50      117    latur
# 15501 2018-10-01       34  24.85       87    latur
# 15502 2018-11-01        9  22.70       28    latur
# 15503 2018-12-01        3  20.65       11    latur

# %%
model.fit(train)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fut = model.make_future_dataframe(periods = 13, freq = 'M')

# %%
forecast = model.predict(fut)

# %%
forecast.tail()
# Out:
#             ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 464 2019-08-31  26.176978   23.481845   27.739134    26.164983    26.190791
# 465 2019-09-30  26.170683   23.770209   27.952383    26.155024    26.188218
# 466 2019-10-31  26.164179   21.561478   25.957785    26.144762    26.185286
# 467 2019-11-30  26.157884   19.612102   23.910650    26.134643    26.183394
# 468 2019-12-31  26.151379   19.244424   23.633166    26.123879    26.180214
#
#      additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 464       -0.667032             -0.667032             -0.667032 -0.667032
# 465       -0.195711             -0.195711             -0.195711 -0.195711
# 466       -2.483106             -2.483106             -2.483106 -2.483106
# 467       -4.503195             -4.503195             -4.503195 -4.503195
# 468       -4.682357             -4.682357             -4.682357 -4.682357
#
#      yearly_lower  yearly_upper  multiplicative_terms  \
# 464     -0.667032     -0.667032                   0.0
# 465     -0.195711     -0.195711                   0.0
# 466     -2.483106     -2.483106                   0.0
# 467     -4.503195     -4.503195                   0.0
# 468     -4.682357     -4.682357                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 464                         0.0                         0.0  25.509946
# 465                         0.0                         0.0  25.974972
# 466                         0.0                         0.0  23.681073
# 467                         0.0                         0.0  21.654689
# 468                         0.0                         0.0  21.469022

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 464 2019-08-31  25.509946   23.481845   27.739134
# 465 2019-09-30  25.974972   23.770209   27.952383
# 466 2019-10-31  23.681073   21.561478   25.957785
# 467 2019-11-30  21.654689   19.612102   23.910650
# 468 2019-12-31  21.469022   19.244424   23.633166

# %%
fig2 = model.plot_components(forecast)

# %%
forecast_2019 = forecast.tail(12)
forecast_2019["Month"] = forecast_2019["ds"].dt.month
print (forecast_2019[["yhat"]].shape,conditions_val[["mid_temp"]].shape)
test = pd.merge(conditions_val[["mid_temp","Month"]],forecast_2019[["yhat","Month"]])
# cols = ['ds','actual','yhat']
from sklearn.metrics import mean_squared_error
print (mean_squared_error(test["mid_temp"], test["yhat"]))
test
# Out:
# (12, 1) (408, 1)
# 10.825090137895623
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      mid_temp  Month       yhat
# 0       23.00      1  24.187589
# 1       19.35      1  24.187589
# 2       20.50      1  24.187589
# 3       21.35      1  24.187589
# 4       20.60      1  24.187589
# ..        ...    ...        ...
# 403     27.50     12  21.469022
# 404     20.65     12  21.469022
# 405     21.30     12  21.469022
# 406     22.40     12  21.469022
# 407     22.40     12  21.469022
#
# [408 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter([test['mid_temp']],test['Month'])
plt.scatter([test['yhat']],test['Month'])
plt.show()
