# %%
import pandas as pd
import numpy as np

# %%
names = ['Year','Month','ppt(mm)','tmax(degC)','tmin(degC)','aet(mm)','PDSI(unitless)','state','district','cluster14','cluster15','cluster18','cluster20','cluster25','cluster27','cluster30','cluster35']

# %%
df = pd.read_csv("C:/Users/H/Documents/agroclimatic_clusters.txt", sep=',', header=None, names=names, index_col=False, engine='python')

# %%
df.head()
# Out:
#    Year  Month  ppt(mm)  tmax(degC)  tmin(degC)  aet(mm)  PDSI(unitless)  \
# 0  1958      1        0        32.1        16.6        2            -0.1
# 1  1958      2        0        34.2        18.4        2            -0.5
# 2  1958      3       17        38.5        21.5       17             0.2
# 3  1958      4       32        40.2        25.3       32             0.8
# 4  1958      5       68        40.5        25.8       65             1.5
#
#          state district  cluster14  cluster15  cluster18  cluster20  \
# 0  maharashtra  solapur          8          7          0          7
# 1  maharashtra  solapur          8          7          0          7
# 2  maharashtra  solapur          8          7          0          7
# 3  maharashtra  solapur          8          7          0          7
# 4  maharashtra  solapur          8          7          0          7
#
#    cluster25  cluster27  cluster30  cluster35
# 0         12         23         15         23
# 1         12         23         15         23
# 2         12         23         15         23
# 3         12         23         15         23
# 4         12         23         15         23

# %%
df['state'].value_counts()
# Out:
# uttar pradesh             52080
# madhya pradesh            35712
# bihar                     27528
# maharashtra               25296
# rajasthan                 23808
# orissa                    22320
# tamil nadu                22320
# karnataka                 20088
# gujarat                   18600
# andhra pradesh            17112
# assam                     17112
# jharkhand                 16368
# west bengal               14136
# haryana                   14136
# punjab                    12648
# chhattisgarh              11904
# arunachal pradesh         11160
# jammu and kashmir         10416
# kerala                    10416
# uttaranchal                9672
# himachal pradesh           8928
# manipur                    6696
# mizoram                    5952
# nagaland                   5952
# meghalaya                  5208
# puducherry                 2976
# sikkim                     2976
# tripura                    2976
# andaman and nicobar        1488
# goa                        1488
# daman and diu              1488
# chandigarh                  744
# lakshadweep                 744
# dadra and nagar haveli      744
# delhi                       744
# Name: state, dtype: int64

# %%
a = []
for i in range(len(df)):
    if df['state'][i]!='karnataka':
        a.append(i)

# %%
df = df.drop(a)

# %%
df.head()
# Out:
#       Year  Month  ppt(mm)  tmax(degC)  tmin(degC)  aet(mm)  PDSI(unitless)  \
# 2232  1958      1        0        31.0        16.8        2            -0.1
# 2233  1958      2        0        33.0        18.8        2            -0.3
# 2234  1958      3       35        36.9        21.3       34             1.0
# 2235  1958      4       58        38.5        24.4       56             1.5
# 2236  1958      5      134        38.5        24.8      128             2.6
#
#           state district  cluster14  cluster15  cluster18  cluster20  \
# 2232  karnataka  bijapur          1          4          0         19
# 2233  karnataka  bijapur          1          4          0         19
# 2234  karnataka  bijapur          1          4          0         19
# 2235  karnataka  bijapur          1          4          0         19
# 2236  karnataka  bijapur          1          4          0         19
#
#       cluster25  cluster27  cluster30  cluster35
# 2232         12          9         15         23
# 2233         12          9         15         23
# 2234         12          9         15         23
# 2235         12          9         15         23
# 2236         12          9         15         23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20088 entries, 2232 to 440447
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            20088 non-null  int64
#  1   Month           20088 non-null  int64
#  2   ppt(mm)         20088 non-null  int64
#  3   tmax(degC)      20088 non-null  float64
#  4   tmin(degC)      20088 non-null  float64
#  5   aet(mm)         20088 non-null  int64
#  6   PDSI(unitless)  20088 non-null  float64
#  7   state           20088 non-null  object
#  8   district        20088 non-null  object
#  9   cluster14       20088 non-null  int64
#  10  cluster15       20088 non-null  int64
#  11  cluster18       20088 non-null  int64
#  12  cluster20       20088 non-null  int64
#  13  cluster25       20088 non-null  int64
#  14  cluster27       20088 non-null  int64
#  15  cluster30       20088 non-null  int64
#  16  cluster35       20088 non-null  int64
# dtypes: float64(3), int64(12), object(2)
# memory usage: 2.8+ MB

# %%
conditions = df[['Year','Month','ppt(mm)','tmax(degC)','tmin(degC)','aet(mm)','PDSI(unitless)','district']]
conditions.shape
# Out:
# (20088, 8)

# %%
conditions.isnull().sum(axis = 0)
# Out:
# Year              0
# Month             0
# ppt(mm)           0
# tmax(degC)        0
# tmin(degC)        0
# aet(mm)           0
# PDSI(unitless)    0
# district          0
# dtype: int64

# %%
conditions["date"] = conditions['Month'].astype('str')+'-'+conditions["Year"].astype(str)
conditions.head()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       Year  Month  ppt(mm)  tmax(degC)  tmin(degC)  aet(mm)  PDSI(unitless)  \
# 2232  1958      1        0        31.0        16.8        2            -0.1
# 2233  1958      2        0        33.0        18.8        2            -0.3
# 2234  1958      3       35        36.9        21.3       34             1.0
# 2235  1958      4       58        38.5        24.4       56             1.5
# 2236  1958      5      134        38.5        24.8      128             2.6
#
#      district    date
# 2232  bijapur  1-1958
# 2233  bijapur  2-1958
# 2234  bijapur  3-1958
# 2235  bijapur  4-1958
# 2236  bijapur  5-1958

# %%
conditions['Day'] = [1] * len(conditions['Month'])
conditions['date'] = pd.to_datetime(conditions[['Year','Month','Day']])
# Out:
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
conditions.head()
# Out:
#       Year  Month  ppt(mm)  tmax(degC)  tmin(degC)  aet(mm)  PDSI(unitless)  \
# 2232  1958      1        0        31.0        16.8        2            -0.1
# 2233  1958      2        0        33.0        18.8        2            -0.3
# 2234  1958      3       35        36.9        21.3       34             1.0
# 2235  1958      4       58        38.5        24.4       56             1.5
# 2236  1958      5      134        38.5        24.8      128             2.6
#
#      district       date  Day
# 2232  bijapur 1958-01-01    1
# 2233  bijapur 1958-02-01    1
# 2234  bijapur 1958-03-01    1
# 2235  bijapur 1958-04-01    1
# 2236  bijapur 1958-05-01    1

# %%
conditions['mid_temp'] = 0.5*(conditions['tmax(degC)']+conditions['tmin(degC)'])
conditions.drop(columns = ['tmax(degC)','tmin(degC)'],inplace = True)
conditions.head()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\H\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       Year  Month  ppt(mm)  aet(mm)  PDSI(unitless) district       date  Day  \
# 2232  1958      1        0        2            -0.1  bijapur 1958-01-01    1
# 2233  1958      2        0        2            -0.3  bijapur 1958-02-01    1
# 2234  1958      3       35       34             1.0  bijapur 1958-03-01    1
# 2235  1958      4       58       56             1.5  bijapur 1958-04-01    1
# 2236  1958      5      134      128             2.6  bijapur 1958-05-01    1
#
#       mid_temp
# 2232     23.90
# 2233     25.90
# 2234     29.10
# 2235     31.45
# 2236     31.65

# %%
conditions.tail()
# Out:
#         Year  Month  ppt(mm)  aet(mm)  PDSI(unitless) district       date  \
# 440443  2019      8       76       73            -1.9   mysore 2019-08-01
# 440444  2019      9       87       83            -1.9   mysore 2019-09-01
# 440445  2019     10      263      105             1.9   mysore 2019-10-01
# 440446  2019     11       44       85             2.5   mysore 2019-11-01
# 440447  2019     12       28       65             3.6   mysore 2019-12-01
#
#         Day  mid_temp
# 440443    1     24.50
# 440444    1     25.10
# 440445    1     24.85
# 440446    1     24.95
# 440447    1     23.15

# %%
conditions_truncated = conditions.loc[(conditions['Year']>1980) & (conditions['Year']<2019)]
conditions_val = conditions.loc[conditions['Year']==2019]

train = conditions_truncated[['date','ppt(mm)','mid_temp','aet(mm)','district']]
train.rename(columns = {'mid_temp':'y'}, inplace = True)

train.reset_index(inplace = True)
train.drop(columns = 'index',inplace = True)
train.head()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\H\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         date  ppt(mm)      y  aet(mm) district
# 0 1981-01-01        5  22.90        8  bijapur
# 1 1981-02-01        0  26.00        2  bijapur
# 2 1981-03-01       35  28.60       35  bijapur
# 3 1981-04-01       43  31.15       42  bijapur
# 4 1981-05-01       45  31.50       43  bijapur

# %%
conditions_val
# Out:
#         Year  Month  ppt(mm)  aet(mm)  PDSI(unitless) district       date  \
# 2964    2019      1        0        3            -2.2  bijapur 2019-01-01
# 2965    2019      2        1        2            -2.2  bijapur 2019-02-01
# 2966    2019      3        2        3            -2.3  bijapur 2019-03-01
# 2967    2019      4       11       12            -2.7  bijapur 2019-04-01
# 2968    2019      5        4        4            -3.5  bijapur 2019-05-01
# ...      ...    ...      ...      ...             ...      ...        ...
# 440443  2019      8       76       73            -1.9   mysore 2019-08-01
# 440444  2019      9       87       83            -1.9   mysore 2019-09-01
# 440445  2019     10      263      105             1.9   mysore 2019-10-01
# 440446  2019     11       44       85             2.5   mysore 2019-11-01
# 440447  2019     12       28       65             3.6   mysore 2019-12-01
#
#         Day  mid_temp
# 2964      1     22.75
# 2965      1     26.15
# 2966      1     29.85
# 2967      1     32.75
# 2968      1     34.05
# ...     ...       ...
# 440443    1     24.50
# 440444    1     25.10
# 440445    1     24.85
# 440446    1     24.95
# 440447    1     23.15
#
# [324 rows x 9 columns]

# %%
from fbprophet import Prophet

# %%
model = Prophet()

# %%
conditions_truncated.rename(columns = {'date':'ds'}, inplace = True)
# Out:
# C:\Users\H\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
train.rename(columns = {'date':'ds'}, inplace = True)

# %%
p = conditions[['mid_temp','Year']]

# %%
p
# Out:
#         mid_temp  Year
# 2232       23.90  1958
# 2233       25.90  1958
# 2234       29.10  1958
# 2235       31.45  1958
# 2236       31.65  1958
# ...          ...   ...
# 440443     24.50  2019
# 440444     25.10  2019
# 440445     24.85  2019
# 440446     24.95  2019
# 440447     23.15  2019
#
# [20088 rows x 2 columns]

# %%
k = []

# %%
p = p.loc[p['Year']==2019]

# %%
p = p.drop(k)

# %%
p
# Out:
#         mid_temp  Year
# 2964       22.75  2019
# 2965       26.15  2019
# 2966       29.85  2019
# 2967       32.75  2019
# 2968       34.05  2019
# ...          ...   ...
# 440443     24.50  2019
# 440444     25.10  2019
# 440445     24.85  2019
# 440446     24.95  2019
# 440447     23.15  2019
#
# [324 rows x 2 columns]

# %%
train.tail()
# Out:
#               ds  ppt(mm)      y  aet(mm) district
# 12307 2018-08-01       71  23.35       71   mysore
# 12308 2018-09-01       64  24.20       63   mysore
# 12309 2018-10-01      136  24.50      118   mysore
# 12310 2018-11-01       18  24.30       22   mysore
# 12311 2018-12-01        8  23.20       11   mysore

# %%
model.fit(train)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fut = model.make_future_dataframe(periods = 13, freq = 'M')

# %%
forecast = model.predict(fut)

# %%
forecast.tail()
# Out:
#             ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 464 2019-08-31  24.929371   20.447606   29.197729    24.929184    24.929588
# 465 2019-09-30  24.930059   20.097804   29.157228    24.929829    24.930332
# 466 2019-10-31  24.930770   18.405056   27.468718    24.930480    24.931115
# 467 2019-11-30  24.931458   17.464006   26.465071    24.931100    24.931867
# 468 2019-12-31  24.932169   17.266158   26.808010    24.931706    24.932649
#
#      additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 464       -0.311348             -0.311348             -0.311348 -0.311348
# 465       -0.231800             -0.231800             -0.231800 -0.231800
# 466       -2.068336             -2.068336             -2.068336 -2.068336
# 467       -2.838910             -2.838910             -2.838910 -2.838910
# 468       -2.864993             -2.864993             -2.864993 -2.864993
#
#      yearly_lower  yearly_upper  multiplicative_terms  \
# 464     -0.311348     -0.311348                   0.0
# 465     -0.231800     -0.231800                   0.0
# 466     -2.068336     -2.068336                   0.0
# 467     -2.838910     -2.838910                   0.0
# 468     -2.864993     -2.864993                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 464                         0.0                         0.0  24.618023
# 465                         0.0                         0.0  24.698259
# 466                         0.0                         0.0  22.862434
# 467                         0.0                         0.0  22.092548
# 468                         0.0                         0.0  22.067175

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 464 2019-08-31  24.618023   20.447606   29.197729
# 465 2019-09-30  24.698259   20.097804   29.157228
# 466 2019-10-31  22.862434   18.405056   27.468718
# 467 2019-11-30  22.092548   17.464006   26.465071
# 468 2019-12-31  22.067175   17.266158   26.808010

# %%
fig2 = model.plot_components(forecast)

# %%
forecast_2019 = forecast.tail(12)
forecast_2019["Month"] = forecast_2019["ds"].dt.month
print (forecast_2019[["yhat"]].shape,conditions_val[["mid_temp"]].shape)
test = pd.merge(conditions_val[["mid_temp","Month"]],forecast_2019[["yhat","Month"]])
# cols = ['ds','actual','yhat']
from sklearn.metrics import mean_squared_error
print (mean_squared_error(test["mid_temp"], test["yhat"]))
test
# Out:
# (12, 1) (324, 1)
# 16.213441187634643
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      mid_temp  Month       yhat
# 0       22.75      1  24.606703
# 1       21.15      1  24.606703
# 2       22.65      1  24.606703
# 3       22.90      1  24.606703
# 4       23.65      1  24.606703
# ..        ...    ...        ...
# 319     22.20     12  22.067175
# 320     23.50     12  22.067175
# 321     23.30     12  22.067175
# 322     21.05     12  22.067175
# 323     23.15     12  22.067175
#
# [324 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter([test['mid_temp']],test['Month'])
plt.scatter([test['yhat']],test['Month'])
plt.show()
