# %%
import pandas as pd
import numpy as np

# %%
names = ['Year','Month','ppt(mm)','tmax(degC)','tmin(degC)','aet(mm)','PDSI(unitless)','state','district','cluster14','cluster15','cluster18','cluster20','cluster25','cluster27','cluster30','cluster35']

# %%
df = pd.read_csv("C:/Users/H/Documents/agroclimatic_clusters.txt", sep=',', header=None, names=names, index_col=False, engine='python')

# %%
df.head()
# Out:
#    Year  Month  ppt(mm)  tmax(degC)  tmin(degC)  aet(mm)  PDSI(unitless)  \
# 0  1958      1        0        32.1        16.6        2            -0.1
# 1  1958      2        0        34.2        18.4        2            -0.5
# 2  1958      3       17        38.5        21.5       17             0.2
# 3  1958      4       32        40.2        25.3       32             0.8
# 4  1958      5       68        40.5        25.8       65             1.5
#
#          state district  cluster14  cluster15  cluster18  cluster20  \
# 0  maharashtra  solapur          8          7          0          7
# 1  maharashtra  solapur          8          7          0          7
# 2  maharashtra  solapur          8          7          0          7
# 3  maharashtra  solapur          8          7          0          7
# 4  maharashtra  solapur          8          7          0          7
#
#    cluster25  cluster27  cluster30  cluster35
# 0         12         23         15         23
# 1         12         23         15         23
# 2         12         23         15         23
# 3         12         23         15         23
# 4         12         23         15         23

# %%
df['state'].value_counts()
# Out:
# uttar pradesh             52080
# madhya pradesh            35712
# bihar                     27528
# maharashtra               25296
# rajasthan                 23808
# orissa                    22320
# tamil nadu                22320
# karnataka                 20088
# gujarat                   18600
# assam                     17112
# andhra pradesh            17112
# jharkhand                 16368
# haryana                   14136
# west bengal               14136
# punjab                    12648
# chhattisgarh              11904
# arunachal pradesh         11160
# kerala                    10416
# jammu and kashmir         10416
# uttaranchal                9672
# himachal pradesh           8928
# manipur                    6696
# nagaland                   5952
# mizoram                    5952
# meghalaya                  5208
# puducherry                 2976
# tripura                    2976
# sikkim                     2976
# goa                        1488
# daman and diu              1488
# andaman and nicobar        1488
# chandigarh                  744
# dadra and nagar haveli      744
# lakshadweep                 744
# delhi                       744
# Name: state, dtype: int64

# %%
a = []
for i in range(len(df)):
    if df['state'][i]!='madhya pradesh':
        a.append(i)

# %%
df = df.drop(a)

# %%
df.head()
# Out:
#        Year  Month  ppt(mm)  tmax(degC)  tmin(degC)  aet(mm)  PDSI(unitless)  \
# 22320  1958      1       12        27.5        11.6       17             0.7
# 22321  1958      2        0        30.0        12.5        4            -0.1
# 22322  1958      3        3        35.6        17.7        6            -0.2
# 22323  1958      4        1        40.2        23.6        4             0.0
# 22324  1958      5        7        42.2        27.4        8             0.0
#
#                 state  district  cluster14  cluster15  cluster18  cluster20  \
# 22320  madhya pradesh  shajapur          5          5          4          3
# 22321  madhya pradesh  shajapur          5          5          4          3
# 22322  madhya pradesh  shajapur          5          5          4          3
# 22323  madhya pradesh  shajapur          5          5          4          3
# 22324  madhya pradesh  shajapur          5          5          4          3
#
#        cluster25  cluster27  cluster30  cluster35
# 22320         16         21          7         25
# 22321         16         21          7         25
# 22322         16         21          7         25
# 22323         16         21          7         25
# 22324         16         21          7         25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35712 entries, 22320 to 438959
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            35712 non-null  int64
#  1   Month           35712 non-null  int64
#  2   ppt(mm)         35712 non-null  int64
#  3   tmax(degC)      35712 non-null  float64
#  4   tmin(degC)      35712 non-null  float64
#  5   aet(mm)         35712 non-null  int64
#  6   PDSI(unitless)  35712 non-null  float64
#  7   state           35712 non-null  object
#  8   district        35712 non-null  object
#  9   cluster14       35712 non-null  int64
#  10  cluster15       35712 non-null  int64
#  11  cluster18       35712 non-null  int64
#  12  cluster20       35712 non-null  int64
#  13  cluster25       35712 non-null  int64
#  14  cluster27       35712 non-null  int64
#  15  cluster30       35712 non-null  int64
#  16  cluster35       35712 non-null  int64
# dtypes: float64(3), int64(12), object(2)
# memory usage: 4.9+ MB

# %%
conditions = df[['Year','Month','ppt(mm)','tmax(degC)','tmin(degC)','aet(mm)','PDSI(unitless)','district']]
conditions.shape
# Out:
# (35712, 8)

# %%
conditions.isnull().sum(axis = 0)
# Out:
# Year              0
# Month             0
# ppt(mm)           0
# tmax(degC)        0
# tmin(degC)        0
# aet(mm)           0
# PDSI(unitless)    0
# district          0
# dtype: int64

# %%
conditions["date"] = conditions['Month'].astype('str')+'-'+conditions["Year"].astype(str)
conditions.head()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Month  ppt(mm)  tmax(degC)  tmin(degC)  aet(mm)  PDSI(unitless)  \
# 22320  1958      1       12        27.5        11.6       17             0.7
# 22321  1958      2        0        30.0        12.5        4            -0.1
# 22322  1958      3        3        35.6        17.7        6            -0.2
# 22323  1958      4        1        40.2        23.6        4             0.0
# 22324  1958      5        7        42.2        27.4        8             0.0
#
#        district    date
# 22320  shajapur  1-1958
# 22321  shajapur  2-1958
# 22322  shajapur  3-1958
# 22323  shajapur  4-1958
# 22324  shajapur  5-1958

# %%
conditions['Day'] = [1] * len(conditions['Month'])
conditions['date'] = pd.to_datetime(conditions[['Year','Month','Day']])
# Out:
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
conditions.head()
# Out:
#        Year  Month  ppt(mm)  tmax(degC)  tmin(degC)  aet(mm)  PDSI(unitless)  \
# 22320  1958      1       12        27.5        11.6       17             0.7
# 22321  1958      2        0        30.0        12.5        4            -0.1
# 22322  1958      3        3        35.6        17.7        6            -0.2
# 22323  1958      4        1        40.2        23.6        4             0.0
# 22324  1958      5        7        42.2        27.4        8             0.0
#
#        district       date  Day
# 22320  shajapur 1958-01-01    1
# 22321  shajapur 1958-02-01    1
# 22322  shajapur 1958-03-01    1
# 22323  shajapur 1958-04-01    1
# 22324  shajapur 1958-05-01    1

# %%
conditions['mid_temp'] = 0.5*(conditions['tmax(degC)']+conditions['tmin(degC)'])
conditions.drop(columns = ['tmax(degC)','tmin(degC)'],inplace = True)
conditions.head()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\H\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#        Year  Month  ppt(mm)  aet(mm)  PDSI(unitless)  district       date  \
# 22320  1958      1       12       17             0.7  shajapur 1958-01-01
# 22321  1958      2        0        4            -0.1  shajapur 1958-02-01
# 22322  1958      3        3        6            -0.2  shajapur 1958-03-01
# 22323  1958      4        1        4             0.0  shajapur 1958-04-01
# 22324  1958      5        7        8             0.0  shajapur 1958-05-01
#
#        Day  mid_temp
# 22320    1     19.55
# 22321    1     21.25
# 22322    1     26.65
# 22323    1     31.90
# 22324    1     34.80

# %%
conditions.tail()
# Out:
#         Year  Month  ppt(mm)  aet(mm)  PDSI(unitless)    district       date  \
# 438955  2019      8      516      102             3.1  ashoknagar 2019-08-01
# 438956  2019      9      456       83             6.8  ashoknagar 2019-09-01
# 438957  2019     10       53       89             7.5  ashoknagar 2019-10-01
# 438958  2019     11       48       68             8.7  ashoknagar 2019-11-01
# 438959  2019     12       16       45             9.2  ashoknagar 2019-12-01
#
#         Day  mid_temp
# 438955    1     27.00
# 438956    1     26.85
# 438957    1     25.25
# 438958    1     22.80
# 438959    1     15.60

# %%
conditions_truncated = conditions.loc[(conditions['Year']>1980) & (conditions['Year']<2019)]
conditions_val = conditions.loc[conditions['Year']==2019]

train = conditions_truncated[['date','ppt(mm)','mid_temp','aet(mm)','district']]
train.rename(columns = {'mid_temp':'y'}, inplace = True)

train.reset_index(inplace = True)
train.drop(columns = 'index',inplace = True)
train.head()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\H\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         date  ppt(mm)      y  aet(mm)  district
# 0 1981-01-01       15  17.65       19  shajapur
# 1 1981-02-01        0  22.00        3  shajapur
# 2 1981-03-01        9  25.95       11  shajapur
# 3 1981-04-01        0  31.35        2  shajapur
# 4 1981-05-01        7  34.15        8  shajapur

# %%
conditions_val
# Out:
#         Year  Month  ppt(mm)  aet(mm)  PDSI(unitless)    district       date  \
# 23052   2019      1        2        7            -1.4    shajapur 2019-01-01
# 23053   2019      2        2        5            -1.2    shajapur 2019-02-01
# 23054   2019      3        1        4            -1.4    shajapur 2019-03-01
# 23055   2019      4        8        9            -0.8    shajapur 2019-04-01
# 23056   2019      5        1        3            -1.1    shajapur 2019-05-01
# ...      ...    ...      ...      ...             ...         ...        ...
# 438955  2019      8      516      102             3.1  ashoknagar 2019-08-01
# 438956  2019      9      456       83             6.8  ashoknagar 2019-09-01
# 438957  2019     10       53       89             7.5  ashoknagar 2019-10-01
# 438958  2019     11       48       68             8.7  ashoknagar 2019-11-01
# 438959  2019     12       16       45             9.2  ashoknagar 2019-12-01
#
#         Day  mid_temp
# 23052     1     16.65
# 23053     1     20.25
# 23054     1     25.55
# 23055     1     31.70
# 23056     1     34.95
# ...     ...       ...
# 438955    1     27.00
# 438956    1     26.85
# 438957    1     25.25
# 438958    1     22.80
# 438959    1     15.60
#
# [576 rows x 9 columns]

# %%
from fbprophet import Prophet

# %%
model = Prophet()

# %%
conditions_truncated.rename(columns = {'date':'ds'}, inplace = True)
# Out:
# C:\Users\H\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
train.rename(columns = {'date':'ds'}, inplace = True)

# %%
p = conditions[['mid_temp','Year']]

# %%
p
# Out:
#         mid_temp  Year
# 22320      19.55  1958
# 22321      21.25  1958
# 22322      26.65  1958
# 22323      31.90  1958
# 22324      34.80  1958
# ...          ...   ...
# 438955     27.00  2019
# 438956     26.85  2019
# 438957     25.25  2019
# 438958     22.80  2019
# 438959     15.60  2019
#
# [35712 rows x 2 columns]

# %%
k = []

# %%
p = p.loc[p['Year']==2019]

# %%
p = p.drop(k)

# %%
p
# Out:
#         mid_temp  Year
# 23052      16.65  2019
# 23053      20.25  2019
# 23054      25.55  2019
# 23055      31.70  2019
# 23056      34.95  2019
# ...          ...   ...
# 438955     27.00  2019
# 438956     26.85  2019
# 438957     25.25  2019
# 438958     22.80  2019
# 438959     15.60  2019
#
# [576 rows x 2 columns]

# %%
train.tail()
# Out:
#               ds  ppt(mm)      y  aet(mm)    district
# 21883 2018-08-01      269  26.75      110  ashoknagar
# 21884 2018-09-01      220  25.85      107  ashoknagar
# 21885 2018-10-01        1  26.25       76  ashoknagar
# 21886 2018-11-01        1  22.20       40  ashoknagar
# 21887 2018-12-01        1  16.10       15  ashoknagar

# %%
model.fit(train)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fut = model.make_future_dataframe(periods = 13, freq = 'M')

# %%
forecast = model.predict(fut)

# %%
forecast.tail()
# Out:
#             ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 464 2019-08-31  25.570731   22.514436   29.830716    25.566902    25.574038
# 465 2019-09-30  25.567184   21.964658   29.616169    25.562240    25.571472
# 466 2019-10-31  25.563519   18.521412   25.658293    25.557684    25.569374
# 467 2019-11-30  25.559971   14.393045   21.723184    25.553082    25.567151
# 468 2019-12-31  25.556306   14.006965   21.469785    25.547897    25.565136
#
#      additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 464        0.585017              0.585017              0.585017  0.585017
# 465        0.108442              0.108442              0.108442  0.108442
# 466       -3.123989             -3.123989             -3.123989 -3.123989
# 467       -7.473701             -7.473701             -7.473701 -7.473701
# 468       -7.946557             -7.946557             -7.946557 -7.946557
#
#      yearly_lower  yearly_upper  multiplicative_terms  \
# 464      0.585017      0.585017                   0.0
# 465      0.108442      0.108442                   0.0
# 466     -3.123989     -3.123989                   0.0
# 467     -7.473701     -7.473701                   0.0
# 468     -7.946557     -7.946557                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 464                         0.0                         0.0  26.155749
# 465                         0.0                         0.0  25.675626
# 466                         0.0                         0.0  22.439530
# 467                         0.0                         0.0  18.086270
# 468                         0.0                         0.0  17.609749

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 464 2019-08-31  26.155749   22.514436   29.830716
# 465 2019-09-30  25.675626   21.964658   29.616169
# 466 2019-10-31  22.439530   18.521412   25.658293
# 467 2019-11-30  18.086270   14.393045   21.723184
# 468 2019-12-31  17.609749   14.006965   21.469785

# %%
fig2 = model.plot_components(forecast)

# %%
forecast_2019 = forecast.tail(12)
forecast_2019["Month"] = forecast_2019["ds"].dt.month
print (forecast_2019[["yhat"]].shape,conditions_val[["mid_temp"]].shape)
test = pd.merge(conditions_val[["mid_temp","Month"]],forecast_2019[["yhat","Month"]])
# cols = ['ds','actual','yhat']
from sklearn.metrics import mean_squared_error
print (mean_squared_error(test["mid_temp"], test["yhat"]))
test
# Out:
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (12, 1) (576, 1)
# 20.470936847970275
#      mid_temp  Month       yhat
# 0       16.65      1  20.621954
# 1       20.30      1  20.621954
# 2       16.00      1  20.621954
# 3       18.85      1  20.621954
# 4       19.70      1  20.621954
# ..        ...    ...        ...
# 571     17.95     12  17.609749
# 572     15.20     12  17.609749
# 573     20.15     12  17.609749
# 574     18.20     12  17.609749
# 575     15.60     12  17.609749
#
# [576 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter([test['mid_temp']],test['Month'])
plt.scatter([test['yhat']],test['Month'])
plt.show()
